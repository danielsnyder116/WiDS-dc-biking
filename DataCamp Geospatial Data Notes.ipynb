# %% [markdown]
# ## Geospatial data - data with location information
#
# ### Two Models for the Real World:
# 1. Raster - encodes as continuous surface, represented by grids
#     - ex. satellite images
# 2. Vector - encodes as discrete objects, represented by points, lines, and polygons
#     - ex.
#
#
# ### Vector Features
# 1. Point - x, y coordinates: (2,10)
# 2. LineString  - list of coordinates: ([(1,2), (1,5), (3,6])
# 3. Polygon - list of coordinates that forms a closed-line area ([(1,2), (1,3), (1,1)])
# 4. MultiPolygon -
#
# ### Vector Feature Attributes

# %%
import pandas as pd
import matplotlib.pyplot as plt

import geopandas
import contextily

# %%
df = pd.read_csv('../Pothole__Last_30_Days.csv')

# %%
df.head()
# Out:
#            X          Y  OBJECTID SERVICECODE SERVICECODEDESCRIPTION  \
# 0 -77.018106  38.822447         1       S0301                Pothole
# 1 -77.057234  38.935178         2       S0301                Pothole
# 2 -76.946425  38.867561         3       S0301                Pothole
# 3 -77.045492  38.917941         4       S0301                Pothole
# 4 -77.075338  38.963316         5       S0301                Pothole
#
#         SERVICETYPECODEDESCRIPTION ORGANIZATIONACRONYM  SERVICECALLCOUNT  \
# 0  Toa-Street & Bridge Maintenance                DDOT                 1
# 1  Toa-Street & Bridge Maintenance                DDOT                 1
# 2  Toa-Street & Bridge Maintenance                DDOT                 1
# 3  Toa-Street & Bridge Maintenance                DDOT                 1
# 4  Toa-Street & Bridge Maintenance                DDOT                 1
#
#                     ADDDATE            RESOLUTIONDATE  ...  \
# ...

# %%
fig, ax = plt.subplots()

#Can't use keyword arguments for x,y, or format with .plot - have to use positional arguments
# ax.plot(x=df['X'], y=df['Y'], fmt='o') - will throw an error]


ax.plot(df['X'], df['Y'],'o')
plt.show()

# %% [markdown]
# This is hard to interpret, so add a background map.
#
# Background Map

# %%
contextily.add_basemap(ax)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\biking\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     471             try:
# --> 472                 cnx.do_handshake()
#     473             except OpenSSL.SSL.WantReadError:
#
# ~\AppData\Local\Continuum\anaconda3\envs\biking\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1914         result = _lib.SSL_do_handshake(self._ssl)
# -> 1915         self._raise_ssl_error(self._ssl, result)
#    1916
#
# ~\AppData\Local\Continuum\anaconda3\envs\biking\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1646         else:
# -> 1647             _raise_current_error()
#    1648
#
# ...

# %%
# !conda config --set ssl_verify no

# %% [markdown]
# contextily.add_basemap(ax)
# plt.show()
#
#
# Spatial specific data formats
# shapefiles,
# GeoJSON, GeoPackage
#
# import geopandas
#
# df = geopandas.read_file('file.json')
#
# GeoDataFrame - dataframe supercharged
# always has geometry column that holds features
# and attributes that describe each geometry
#
# df.geometry - GeoSeries
#
# df.geometry.area - returns area of each geometry
# all features of normal pandas still work
#
#
# geometries
# df.plot()
